# %%
import pandas as pd

# Import the market research dataset

file_path21 = r"LPWA_global.xlsx"
file_path22 = r"LPWA_EU.xlsx"
file_path23 = r"Mobile_global.xlsx"
file_path24 = r"Mobile_EU.xlsx"
file_path25 = r"Satellite_global.xlsx"
file_path26 = r"Satellite_EU.xlsx"

try:
    df_LPWA_global = pd.read_excel(file_path21)
#    print("Market Research data loaded successfully. Here are the first few rows:")
#    print(df.head())
    data_types_df = df_LPWA_global.dtypes
#    print(data_types_df)
except Exception as e:
    print("An error occurred while loading the file:", e)

try:
    df_LPWA_EU = pd.read_excel(file_path22)
#    print("Market Research data loaded successfully. Here are the first few rows:")
#    print(df.head())
    data_types_df = df_LPWA_EU.dtypes
#    print(data_types_df)
except Exception as e:
    print("An error occurred while loading the file:", e)
    
try:
    df_Mobile_global = pd.read_excel(file_path23)
#    print("Market Research data loaded successfully. Here are the first few rows:")
#    print(df.head())
    data_types_df = df_Mobile_global.dtypes
#    print(data_types_df)
except Exception as e:
    print("An error occurred while loading the file:", e)


try:
    df_Mobile_EU = pd.read_excel(file_path24)
#    print("Market Research data loaded successfully. Here are the first few rows:")
#    print(df.head())
    data_types_df = df_Mobile_EU.dtypes
#    print(data_types_df)
except Exception as e:
    print("An error occurred while loading the file:", e)

try:
    df_Satellite_global = pd.read_excel(file_path25)
#    print("Market Research data loaded successfully. Here are the first few rows:")
#    print(df.head())
    data_types_df = df_Satellite_global.dtypes
#    print(data_types_df)
except Exception as e:
    print("An error occurred while loading the file:", e)

try:
    df_Satellite_EU = pd.read_excel(file_path26)
#    print("Market Research data loaded successfully. Here are the first few rows:")
#    print(df.head())
    data_types_df = df_Satellite_EU.dtypes
#    print(data_types_df)
except Exception as e:
    print("An error occurred while loading the file:", e)
